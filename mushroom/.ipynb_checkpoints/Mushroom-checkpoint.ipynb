# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('agaricus-lepiota.xlsx')  # Replace with the correct file path

# %%
data
# Out:
#      class label cap-shape cap-surface cap-color bruises? odor  \
# 0              p         x           s         n        t    p
# 1              e         x           s         y        t    a
# 2              e         b           s         w        t    l
# 3              p         x           y         w        t    p
# 4              e         x           s         g        f    n
# ...          ...       ...         ...       ...      ...  ...
# 8119           e         k           s         n        f    n
# 8120           e         x           s         n        f    n
# 8121           e         f           s         n        f    n
# 8122           p         k           y         n        f    y
# 8123           e         x           s         n        f    n
#
#      gill-attachment gill-spacing gill-size gill-color  ...  \
# 0                  f            c         n          k  ...
# 1                  f            c         b          k  ...
# ...

# %%
data.describe()
# Out:
#        class label cap-shape cap-surface cap-color bruises?  odor  \
# count         8124      8124        8124      8124     8124  8124
# unique           2         6           4        10        2     9
# top              e         x           y         n        f     n
# freq          4208      3656        3244      2284     4748  3528
#
#        gill-attachment gill-spacing gill-size gill-color  ...  \
# count             8124         8124      8124       8124  ...
# unique               2            2         2         12  ...
# top                  f            c         b          b  ...
# freq              7914         6812      5612       1728  ...
#
#        stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# count                      8124                   8124                   8124
# unique                        4                      9                      9
# top                           s                      w                      w
# ...

# %%
data.columns
# Out:
# Index(['class label', 'cap-shape', 'cap-surface', 'cap-color', 'bruises?',
#        'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
label_encoders = {}

# Iterate through each column in the DataFrame
for column in data.columns:
    if data[column].dtype == 'object':  # Process only categorical columns
        le = LabelEncoder()
        data[column] = le.fit_transform(data[column])
        label_encoders[column] = le

# %%
data
# Out:
#       class label  cap-shape  cap-surface  cap-color  bruises?  odor  \
# 0               1          5            2          4         1     6
# 1               0          5            2          9         1     0
# 2               0          0            2          8         1     3
# 3               1          5            3          8         1     6
# 4               0          5            2          3         0     5
# ...           ...        ...          ...        ...       ...   ...
# 8119            0          3            2          4         0     5
# 8120            0          5            2          4         0     5
# 8121            0          2            2          4         0     5
# 8122            1          3            3          4         0     8
# 8123            0          5            2          4         0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# ...

# %%
x = data.drop('class label', axis=1)  # Replace with the actual column name
y = data['class label']

# %%
x
# Out:
#       cap-shape  cap-surface  cap-color  bruises?  odor  gill-attachment  \
# 0             5            2          4         1     6                1
# 1             5            2          9         1     0                1
# 2             0            2          8         1     3                1
# 3             5            3          8         1     6                1
# 4             5            2          3         0     5                1
# ...         ...          ...        ...       ...   ...              ...
# 8119          3            2          4         0     5                0
# 8120          5            2          4         0     5                0
# 8121          2            2          4         0     5                0
# 8122          3            3          4         0     8                1
# 8123          5            2          4         0     5                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class label, Length: 8124, dtype: int32

# %%
def train_test_split_2(x, y, test_size=0.2, random_state=None):
 
    if random_state is not None:
        np.random.seed(random_state)
    
    # Shuffle the data
    indices = np.arange(x.shape[0])
    np.random.shuffle(indices)
    
    # Calculate the number of test samples
    test_size = int(len(x) * test_size)
    
    # Split the indices
    test_indices = indices[:test_size]
    train_indices = indices[test_size:]
    
    # Split the data
  # Split the data using integer indexers
    x_train, x_test = x.iloc[train_indices], x.iloc[test_indices]
    y_train, y_test = y.iloc[train_indices], y.iloc[test_indices]
    
    
    return X_train, X_test, y_train, y_test

# %%
x_train, x_test, y_train, y_test=train_test_split_2(x,y,random_state=50)

# %%
x_train.shape
# Out:
# (6500, 22)

# %%
x_train
# Out:
#       cap-shape  cap-surface  cap-color  bruises?  odor  gill-attachment  \
# 3871          5            0          3         0     2                1
# 6051          2            2          4         0     2                1
# 7661          5            2          4         0     8                1
# 3668          2            3          2         1     5                1
# 5124          2            2          8         1     2                1
# ...         ...          ...        ...       ...   ...              ...
# 7457          3            2          4         0     7                1
# 6253          5            3          2         0     7                1
# 1931          0            2          8         1     0                1
# 5600          5            3          4         0     8                1
# 5808          5            2          0         1     2                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
x_test.shape
# Out:
# (1624, 22)

# %%
print(data['class label'].value_counts())
# Out:
# 0    4208
# 1    3916
# Name: class label, dtype: int64

# %%
# Visualizations
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='class label', y='cap-shape', data=data)
plt.title('Boxplot ofcap-shape by class label')
plt.show()

# %%
# Visualizations
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='class label', y='bruises?', data=data)
plt.title('Boxplot ofbruises? by class label')
plt.show()

# %%
# Correlation Matrix
plt.figure(figsize=(20,15))
sns.heatmap(data.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Identify categorical columns
categorical_columns = data.select_dtypes(include=['object']).columns

# Encode categorical data using Label Encoding
for column in categorical_columns:
    data[column] = data[column].astype('category').cat.codes

# Generate the correlation matrix
plt.figure(figsize=(20, 15))
sns.heatmap(data.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix (Encoded Data)')
plt.show()

# Correlation with target variable (optional)
target_corr = data.corr()['class label'].sort_values(ascending=False)
plt.figure(figsize=(10, 8))
sns.barplot(x=target_corr.index, y=target_corr.values, palette='coolwarm')
plt.xticks(rotation=90)
plt.title('Correlation with Target Variable')
plt.show()

# %%
import numpy as np
from collections import Counter


class Node:
    """
    A class to represent a single node in the decision tree.
    """

    def __init__(self, feature=None, threshold=None, left=None, right=None, *, value=None):
        self.feature = feature  # Index of the feature used for splitting
        self.threshold = threshold  # Threshold value for splitting
        self.left = left  # Left child node
        self.right = right  # Right child node
        self.value = value  # Prediction value for leaf nodes

    def is_leaf_node(self):
        """
        Check if the current node is a leaf node.
        """
        return self.value is not None


class DecisionTree:
    """
    A class to represent the decision tree.
    """

    def __init__(self, min_samples_split=2, max_depth=100, n_features=None):
        self.min_samples_split = min_samples_split  # Minimum samples required to split a node
        self.max_depth = max_depth  # Maximum depth of the tree
        self.n_features = n_features  # Number of features to consider for splitting
        self.root = None  # Root node of the decision tree

    def fit(self, X, y):
        """
        Fit the decision tree to the training data.

        Parameters:
        - X: Features of the training data (numpy array).
        - y: Labels of the training data (numpy array).
        """
        self.n_features = X.shape[1] if not self.n_features else min(X.shape[1], self.n_features)
        self.root = self._grow_tree(X, y)

    def _grow_tree(self, X, y, depth=0):
        """
        Recursively grow the decision tree.

        Parameters:
        - X: Features of the current dataset.
        - y: Labels of the current dataset.
        - depth: Current depth of the tree.

        Returns:
        - A Node object representing the root of the tree (or subtree).
        """
        n_samples, n_feats = X.shape
        n_labels = len(np.unique(y))

        # Check the stopping criteria
        if depth >= self.max_depth or n_labels == 1 or n_samples < self.min_samples_split:
            leaf_value = self._most_common_label(y)
            return Node(value=leaf_value)

        # Randomly select a subset of features to consider for splitting
        feature_indices = np.random.choice(n_feats, self.n_features, replace=False)

        # Find the best split
        best_feature, best_threshold = self._best_split(X, y, feature_indices)

        # Split the dataset
        left_indices = X[:, best_feature] <= best_threshold
        right_indices = X[:, best_feature] > best_threshold
        left = self._grow_tree(X[left_indices], y[left_indices], depth + 1)
        right = self._grow_tree(X[right_indices], y[right_indices], depth + 1)

        return Node(feature=best_feature, threshold=best_threshold, left=left, right=right)

    def _best_split(self, X, y, feature_indices):
        """
        Find the best feature and threshold to split the data.

        Parameters:
        - X: Features of the current dataset.
        - y: Labels of the current dataset.
        - feature_indices: Indices of the features to consider.

        Returns:
        - best_feature: Index of the best feature.
        - best_threshold: Threshold value for the best split.
        """
        best_gain = -1
        split_feature, split_threshold = None, None

        for feature in feature_indices:
            thresholds = np.unique(X[:, feature])
            for threshold in thresholds:
                # Calculate information gain
                gain = self._information_gain(X, y, feature, threshold)
                if gain > best_gain:
                    best_gain = gain
                    split_feature = feature
                    split_threshold = threshold

        return split_feature, split_threshold

    def _information_gain(self, X, y, feature, threshold):
        """
        Calculate the information gain from a potential split.

        Parameters:
        - X: Features of the current dataset.
        - y: Labels of the current dataset.
        - feature: The feature to split on.
        - threshold: The threshold value for the split.

        Returns:
        - Information gain from the split.
        """
        # Split the data
        left_indices = X[:, feature] <= threshold
        right_indices = X[:, feature] > threshold

        if len(y[left_indices]) == 0 or len(y[right_indices]) == 0:
            return 0

        # Calculate entropy before the split
        parent_entropy = self._entropy(y)

        # Calculate entropy after the split
        n = len(y)
        n_left, n_right = len(y[left_indices]), len(y[right_indices])
        child_entropy = (n_left / n) * self._entropy(y[left_indices]) + (n_right / n) * self._entropy(y[right_indices])

        # Information gain is the reduction in entropy
        return parent_entropy - child_entropy

    def _entropy(self, y):
        """
        Calculate the entropy of the dataset.

        Parameters:
        - y: Labels of the dataset (numpy array).

        Returns:
        - Entropy value.
        """
        hist = np.bincount(y)
        ps = hist / len(y) if len(y) > 0 else np.zeros_like(hist)
        return -np.sum([p * np.log2(p) for p in ps if p > 0])

    def _most_common_label(self, y):
        """
        Find the most common label in the dataset.

        Parameters:
        - y: Labels of the dataset.

        Returns:
        - The most frequent label in the dataset.
        """
        if len(y) == 0:
            return None
        counter = Counter(y)
        most_common = counter.most_common(1)
        return most_common[0][0] if most_common else None

    def predict(self, X):
        """
        Predict the labels for a dataset.

        Parameters:
        - X: Features of the dataset (numpy array).

        Returns:
        - Predictions for each sample in the dataset.
        """
        return np.array([self._traverse_tree(x, self.root) for x in X])

    def _traverse_tree(self, x, node):
        """
        Traverse the decision tree to make a prediction.

        Parameters:
        - x: A single data point.
        - node: The current node in the tree.

        Returns:
        - The predicted label for the data point.
        """
        if node.is_leaf_node():
            return node.value

        if x[node.feature] <= node.threshold:
            return self._traverse_tree(x, node.left)
        return self._traverse_tree(x, node.right)


# Using the Decision Tree

from sklearn import datasets
from sklearn.model_selection import train_test_split

# Load the breast cancer dataset
data = datasets.load_breast_cancer()
X, y = data.data, data.target

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# Initialize the decision tree classifier
clf = DecisionTree(max_depth=10)

# Train the decision tree on the training data
clf.fit(X_train, y_train)

# Predict labels for the test data
predictions = clf.predict(X_test)

# Evaluate the accuracy
accuracy = np.mean(predictions == y_test)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 91.23%
